# %% [markdown]
# ### Praca z danymi nieustruktyzowanymi III

# %% [markdown]
# ![image.png](attachment:48785952-856b-42a1-bc6e-327dfee58856.png)

# %% [markdown]
# To teraz na rzeczywistej stronie.
#
# Wyciągnijmy tytuły wszystkich artykułów, które znajdują się obecnie na portalu interia.

# %% [markdown]
# Zadanie 2 i Zadanie 3
