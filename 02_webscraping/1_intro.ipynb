# %% [markdown]
# ### Praca z danymi nieustruktyzowanymi I

# %% [markdown]
# ![image.png](attachment:48785952-856b-42a1-bc6e-327dfee58856.png)

# %% [markdown]
# Popatrzmy na plik `main.html`.
#
# Chcielibyśmy znaleźć jaki jest tytuł strony. W jaki sposób możemy to zrobić ?

# %%
# Wczytajmy zawartość

# %% [markdown]
# Jak teraz wyciągnąć z tego NAPISU tytuł ?
#
# Jest kilka sposobów. Możemy na przykład:
# - pociąć napis w odpowiednim miejscu i wyciągnąć tylko wycinek zawierający tylko tytuł strony
# - użyć wyrażeń regularnych
#
# Ale jest też w pythonie biblioteka dedykowana do parsowania plików html - `BeautifulSoup`.

# %% [markdown]
# Bibliotekę beautifulsoup instalujemy komendą:
#
# <code>pip install beautifulsoup4
# </code>

# %% [markdown]
# #### Wstęp do bilbioteki [BeautifulSoup](

# %% [markdown]
# Dokumentacja biblioteki znajduje się na stronie https://www.crummy.com/software/BeautifulSoup/bs4/doc/:
#
# ![image.png](attachment:b55f592a-6182-4108-9206-87ae56fd8370.png)

# %% [markdown]
# Do najpopularniejszych metod klasy BeautifulSoup należą:
# - `.find()` - wyszukuje i zwraca pierwszy, napotkany element, pasujący do wzorca wyszukiwania.
# - `.find_all()` - to samo, co .find(), ale zwraca listę pasujących elementów.
# - `.select_one()` - wyszukuje i zwraca pierwszy, napotkany element pasujący do selektora CSS.
# - `.select()` - to samo, co .select_one(), ale zwraca listę pasujących elementów.

# %% [markdown]
# #### 1. metoda [find](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find)

# %% [markdown]
# #### 2. metoda [find_all](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#calling-a-tag-is-like-calling-find-all)

# %%
# wyciągamy po klasie

# %%
# wyciągamy po id

# %% [markdown]
# #### 3. metoda `select_one`

# %% [markdown]
# #### 4. metoda `select`

# %% [markdown]
# Selektory css

# %%
# Szukamy elementów otagowanych - span

# %%
# Szukamy elementu o id="dwa"

# %%
# Szukamy elementu o klasie class="name"
